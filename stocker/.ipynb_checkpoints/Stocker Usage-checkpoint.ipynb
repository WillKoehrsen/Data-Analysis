# %%
# Command for plotting in the notebook
# %matplotlib inline

# %%
from stocker import Stocker

# %%
microsoft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-01-16.

# %%
microsoft.plot_stock()
# Out:
# Maximum price = $89.58 on 2018-01-12.
# Minimum price = $0.06 on 1986-03-24.
# Current price = $88.35.

# %%
microsoft.buy_and_hold(start_date='1986-03-13', end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
model, future = microsoft.create_prophet_model()
# Out:
# Predicted Price on 2019-01-16 = $114.12

# %%
model.plot_components(future)

# %%
microsoft.evaluate_prediction(start_date='2017-01-11', end_date='2018-01-11')
# Out:
# You played the stock market in MSFT from 2017-01-11 to 2018-01-11 with 1000 shares.
#
# Predicted price on 2018-01-10 = $76.73.
# Actual price on    2018-01-10 = $87.82.
#
# When the model predicted an increase, the price increased 53.22% of the time.
# When the model predicted a decrease, the price decreased  37.97% of the time.
#
# The total profit using the Prophet model = $17592.72.
# The Buy and Hold strategy profit =         $26004.12.
#
# Thanks for playing the stock market!

# %%
microsoft.changepoint_date_analysis(term='microsoft stock')
# Out:
# Changepoints sorted by slope rate of change (2nd derivative):
#
#           Date  Adj. Close     delta
# 48  2015-03-30   38.238066  2.580296
# 337 2016-05-20   48.886934  2.231580
# 409 2016-09-01   55.966886 -2.053965
# 72  2015-05-04   45.034285 -2.040387
# 313 2016-04-18   54.141111 -1.936257

# %%
microsoft.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])

# %%
microsoft.changepoint_prior_validation(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
#      cps  train_err  train_range   test_err  test_range
# 0  0.001   1.629470     5.237887  11.831290    5.241211
# 1  0.050   1.002942     3.291310   6.801833   13.341915
# 2  0.100   0.885392     2.921408   5.856096   22.233777
# 3  0.200   0.773537     2.576631   3.276140   43.758783

# %%
microsoft.changepoint_prior_validation(changepoint_priors=[0.2, 0.3, 0.4, 0.5])
# Out:
#    cps  train_err  train_range  test_err  test_range
# 0  0.2   0.773537     2.580727  3.276140   44.642684
# 1  0.3   0.706126     2.374294  2.326242   75.183967
# 2  0.4   0.690092     2.319779  3.084256   78.200837
# 3  0.5   0.685347     2.304311  3.126251   81.294527

# %%
microsoft.changepoint_prior_scale = 0.3

# %%
microsoft.predict_future(days=15)
# Out:
# Predicted Increase:
#
#          Date   estimate    change      upper      lower
# 1  2018-01-17  87.635150  0.130816  88.835986  86.464106
# 2  2018-01-18  87.729426  0.094275  88.914711  86.430019
# 3  2018-01-19  87.736804  0.007378  88.991836  86.429374
# 6  2018-01-22  87.781400  0.095037  89.111296  86.577261
# 7  2018-01-23  87.939198  0.157798  89.265734  86.686264
# 8  2018-01-24  88.053863  0.114665  89.311386  86.691862
# 12 2018-01-28  88.012826  0.041900  89.264327  86.538341
# 13 2018-01-29  88.195298  0.182471  89.488589  86.788536
# 14 2018-01-30  88.342171  0.146873  89.704903  87.007622
#
# Predicted Decrease:
#
#          Date   estimate    change      upper      lower
# 5  2018-01-21  87.686363 -0.050441  88.995655  86.425502
# 9  2018-01-25  88.052388 -0.001475  89.266484  86.746467
# 10 2018-01-26  87.970926 -0.081462  89.197050  86.571711
# 15 2018-01-31  88.335110 -0.007060  89.590512  86.932395
