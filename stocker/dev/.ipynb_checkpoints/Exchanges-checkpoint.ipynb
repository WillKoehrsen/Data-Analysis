# %% [markdown]
# # Purpose: Investigate Additional Exchanges

# %% [markdown]
# What other stock exchange databases besides WIKI will work with Stocker? The main issue is making sure the data is daily and finding the right column to analyze.

# %%
# BSE and NSE
import quandl
import pandas as pd
import numpy as np
import fbprophet
import pytrends
from pytrends.request import TrendReq

# matplotlib pyplot for plotting
import matplotlib.pyplot as plt

import matplotlib

# %%
stock = quandl.get('NSE/TECHM')

# %%
stock.head()
# Out:
#              Open   High     Low    Last   Close  Total Trade Quantity  \
# Date
# 2006-08-28  521.0  569.0  502.00  553.00  554.25            15166163.0
# 2006-08-29  555.0  563.9  535.55  536.10  539.30             3929113.0
# 2006-08-30  537.0  542.9  521.50  529.00  528.10             2034983.0
# 2006-08-31  525.0  544.0  515.00  539.35  538.45             1670990.0
# 2006-09-01  539.0  549.0  535.10  541.35  541.85             1176195.0
#
#             Turnover (Lacs)
# Date
# 2006-08-28         83717.60
# 2006-08-29         21515.30
# 2006-08-30         10776.30
# 2006-08-31          8904.46
# 2006-09-01          6380.39

# %%
stock2 = quandl.get('BSE/CPSE')

# %%
stock2.head()
# Out:
#             Open  High  Low    Close
# Date
# 2008-07-08   NaN   NaN  NaN  1415.09
# 2008-07-09   NaN   NaN  NaN  1471.62
# 2008-07-10   NaN   NaN  NaN  1486.05
# 2008-07-11   NaN   NaN  NaN  1446.56
# 2008-07-14   NaN   NaN  NaN  1460.94

# %%
import sys

path_to_stocker = 'C:/Users/Will Koehrsen/Documents/Data-Analysis/stocker'
sys.path.insert(0, path_to_stocker)

# %%
from stocker import Stocker

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
cpse = Stocker(ticker = 'CPSE', exchange='BSE')
# Out:
# CPSE Stocker Initialized. Data covers 2008-07-08 to 2018-01-31.

# %%
cpse.changepoint_date_analysis(search='India')
# Out:
#  Top Related Queries:
#
#             query  value
# 0     india times    100
# 1  times of india     94
# 2   bank of india     81
# 3   india cricket     78
# 4      news india     67
#
#  Rising Related Queries:
#
#                          query  value
# 0  india national cricket team  69000
# 1      india vs sri lanka 2017  11550
# 2           rio olympics india   9250
# 3    samsung j2 price in india   8700
# 4      india vs australia 2017   7550

# %%
techm = Stocker('TECHM', 'NSE')
# Out:
# TECHM Stocker Initialized. Data covers 2006-08-28 to 2018-01-31.

# %%
techm.plot_stock()
# Out:
# Maximum Adj. Close = 2921.65 on 2015-03-11.
# Minimum Adj. Close = 209.30 on 2009-01-23.
# Current Adj. Close = 612.65 on 2018-01-31.

# %%
techm.changepoint_prior_analysis()

# %%
msft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-01-30.

# %%
msft.changepoint_prior_analysis()

# %%
msft.changepoint_date_analysis(search='MSFT')
# Out:
#  Top Related Queries:
#
#               query  value
# 0        msft stock    100
# 1        msft price     43
# 2  msft stock price     35
# 3              aapl     25
# 4              amzn     14
#
#  Rising Related Queries:
#
#                     query  value
# 0              snap stock  39500
# 1                alphabet  23750
# 2  amzn stock price today  18900
# 3       msft connect test  16150
# 4          snapchat stock  13700
