# %% [markdown]
# # Introduction: Interacting with Slack from Python
#
# In this notebook, we will use `Slacker` to interact with Slack. This allows us to send messages and upload files, which can be useful when training models, or monitoring scripts (or just for fun of course)!

# %%
# !pip install -q -U Slacker
# Out:
# distributed 1.20.2 has requirement tornado>=4.5.1, but you'll have tornado 4.3 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

# Slacker 
from slacker import Slacker

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Get a Slack Legacy API Token
#
# https://api.slack.com/custom-integrations/legacy-tokens
#
# Store in a safe location (not on GitHub)!

# %% [markdown]
# Read in slack api token.

# %%
with open('C:/Users/willk/OneDrive/Desktop/slack_api_python.txt', 'r') as f:
    slack_api_token = f.read()

# %% [markdown]
# Authenticate with slack

# %%
slack = Slacker(slack_api_token)
channels = slack.channels.list()

for channel in channels.body['channels']:
    print(f'Channel {channel["name"]} Purpose: {channel["purpose"]["value"]}')
# Out:
# Channel general Purpose: This channel is for workspace-wide communication and announcements. All members are in this channel.
# Channel random Purpose: A place for non-work-related flimflam, faffing, hodge-podge or jibber-jabber you'd prefer to keep out of more focused work-related channels.
# Channel slack_interaction Purpose: To interact with Slack from Python
# Channel testing_exp Purpose: Experimental testing of interactions.

# %%
from PIL import Image
import requests
url = user['profile']['image_192']
im = Image.open(requests.get(url, stream=True).raw)
plt.imshow(im)

# %%
PIL.Image.from

# %%
from IPython.display import Image
from PIL import Image
import PIL
users = slack.users.list()

for user in users.body['members']:
    # Print some information
    print(f'\nUser: {user["name"]}, Real Name: {user["real_name"]}, Time Zone: {user["tz_label"]}.')
    print(f'Current Status: {user["profile"]["status_text"]}')
    # Get image data and show
    plt.figure(facecolor = 'w')
    plt.imshow(Image.open(requests.get(user['profile']['image_192'], stream=True).raw))
    plt.axis('off');
    plt.grid('off');
    plt.show();
# Out:
# User: wjk68, Real Name: Will Koehrsen, Time Zone: Eastern Daylight Time.
# Current Status: Running
# User: slackbot, Real Name: slackbot, Time Zone: Pacific Daylight Time.
# Current Status:

# %%
plt.plot(np.random.randn(100), np.random.randn(100), 'ro')
plt.savefig('first_plot.png')

# %%
slack.files.upload('first_plot.png', channels = ['testing_exp', 'slack_interaction']);

# %%
Image(user['profile']['image_192'])

# %%
Image('https://secure.gravatar.com/avatar/f85b7564fd35d5c86054b95090052d94.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0025-192.png')

# %%
users.body['members']
# Out:
# [{'color': '9f69e7',
#   'deleted': False,
#   'has_2fa': False,
#   'id': 'UCEKVNHPH',
#   'is_admin': True,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_owner': True,
#   'is_primary_owner': True,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'wjk68',
#   'profile': {'avatar_hash': 'af6fa36ec0b3',
#    'display_name': 'willk',
#    'display_name_normalized': 'willk',
#    'email': 'wjk68@case.edu',
#    'first_name': 'Will',
#    'image_1024': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2018-08-22/421515326835_af6fa36ec0b3f86e86ae_original.jpg',
#    'is_custom_image': True,
#    'last_name': 'Koehrsen',
#    'phone': '',
#    'real_name': 'Will Koehrsen',
#    'real_name_normalized': 'Will Koehrsen',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'TCD256PSM',
#    'title': ''},
#   'real_name': 'Will Koehrsen',
#   'team_id': 'TCD256PSM',
#   'tz': 'America/New_York',
#   'tz_label': 'Eastern Daylight Time',
#   'tz_offset': -14400,
#   'updated': 1534989027},
#  {'color': '757575',
#   'deleted': False,
#   'id': 'USLACKBOT',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'slackbot',
#   'profile': {'always_active': True,
#    'avatar_hash': 'sv1444671949',
#    'display_name': 'slackbot',
#    'display_name_normalized': 'slackbot',
#    'fields': None,
#    'first_name': 'slackbot',
#    'image_192': 'https://a.slack-edge.com/66f9/img/slackbot_192.png',
#    'image_24': 'https://a.slack-edge.com/0180/img/slackbot_24.png',
#    'image_32': 'https://a.slack-edge.com/7f1a0/plugins/slackbot/assets/service_32.png',
#    'image_48': 'https://a.slack-edge.com/7f1a0/plugins/slackbot/assets/service_48.png',
#    'image_512': 'https://a.slack-edge.com/1801/img/slackbot_512.png',
#    'image_72': 'https://a.slack-edge.com/0180/img/slackbot_72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'slackbot',
#    'real_name_normalized': 'slackbot',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'TCD256PSM',
#    'title': ''},
#   'real_name': 'slackbot',
#   'team_id': 'TCD256PSM',
#   'tz': None,
#   'tz_label': 'Pacific Daylight Time',
#   'tz_offset': -25200,
#   'updated': 0}]

# %%
x = slack.channels.list()

# %%
x.body
# Out:
# {'channels': [{'created': 1534988091,
#    'creator': 'UCEKVNHPH',
#    'id': 'CCCT28F08',
#    'is_archived': False,
#    'is_channel': True,
#    'is_general': True,
#    'is_member': True,
#    'is_mpim': False,
#    'is_org_shared': False,
#    'is_private': False,
#    'is_shared': False,
#    'members': ['UCEKVNHPH'],
#    'name': 'general',
#    'name_normalized': 'general',
#    'num_members': 1,
#    'previous_names': [],
#    'purpose': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988091,
#     'value': 'This channel is for workspace-wide communication and announcements. All members are in this channel.'},
#    'topic': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988091,
#     'value': 'Company-wide announcements and work-based matters'},
#    'unlinked': 0},
#   {'created': 1534988091,
#    'creator': 'UCEKVNHPH',
#    'id': 'CCDP3ES85',
#    'is_archived': False,
#    'is_channel': True,
#    'is_general': False,
#    'is_member': True,
#    'is_mpim': False,
#    'is_org_shared': False,
#    'is_private': False,
#    'is_shared': False,
#    'members': ['UCEKVNHPH'],
#    'name': 'random',
#    'name_normalized': 'random',
#    'num_members': 1,
#    'previous_names': [],
#    'purpose': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988091,
#     'value': "A place for non-work-related flimflam, faffing, hodge-podge or jibber-jabber you'd prefer to keep out of more focused work-related channels."},
#    'topic': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988091,
#     'value': 'Non-work banter and water cooler conversation'},
#    'unlinked': 0},
#   {'created': 1534988443,
#    'creator': 'UCEKVNHPH',
#    'id': 'CCDC464LU',
#    'is_archived': False,
#    'is_channel': True,
#    'is_general': False,
#    'is_member': True,
#    'is_mpim': False,
#    'is_org_shared': False,
#    'is_private': False,
#    'is_shared': False,
#    'members': ['UCEKVNHPH'],
#    'name': 'slack_interaction',
#    'name_normalized': 'slack_interaction',
#    'num_members': 1,
#    'previous_names': [],
#    'purpose': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988444,
#     'value': 'To interact with Slack from Python'},
#    'topic': {'creator': '', 'last_set': 0, 'value': ''},
#    'unlinked': 0},
#   {'created': 1534988457,
#    'creator': 'UCEKVNHPH',
#    'id': 'CCD27690R',
#    'is_archived': False,
#    'is_channel': True,
#    'is_general': False,
#    'is_member': True,
#    'is_mpim': False,
#    'is_org_shared': False,
#    'is_private': False,
#    'is_shared': False,
#    'members': ['UCEKVNHPH'],
#    'name': 'testing_exp',
#    'name_normalized': 'testing_exp',
#    'num_members': 1,
#    'previous_names': [],
#    'purpose': {'creator': 'UCEKVNHPH',
#     'last_set': 1534988457,
#     'value': 'Experimental testing of interactions.'},
#    'topic': {'creator': '', 'last_set': 0, 'value': ''},
#    'unlinked': 0}],
#  'ok': True}
